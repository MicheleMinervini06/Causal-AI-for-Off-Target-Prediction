# %% [markdown]
# # 05 Explainability
# Analisi SHAP, Integrated Gradients e metriche BAS/ESS/CAET.

# %%
import numpy as np
from evaluation.bas import biological_alignment_score
biological_alignment_score(np.array([[1, 0, 0]]), np.array([1, 0, 0]))
