# %% [markdown]
# # 02 DAG Validation
# Validazione delle feature biologiche e dei vincoli del DAG.

# %%
import pandas as pd
from dag.validate import validate_dag_edges
df = pd.DataFrame()
validate_dag_edges(df)
